# %% [markdown]
# # Python essentials
#
# ## Standard python
#
# * code comments
#
#     `# <your_comment>`
#
# * print
#
#     `print()`
#
# * variables
#
#     `<varible_name> = <value>`
#
# * define a function
#
#     `def <your_function>():`
#
# * run a function
#
#     `<varible_name> = <your_function>(<your_input>)`
#
# * import package/library
#
#     `import pandas as pd`
#
# * for loop
#
#         list = [1, 2, 3]
#
#         for item in list:
#             print(item)
#
#         [output]:
#         1
#         2
#         3
#
# * if else
#
#         if <condition>:
#             <code>
#         else:
#             <code>
#
# ## Packages and Libraries
#
# * Pandas
#
#     * Manage and manipulate data
#     * Similar to excel
#
# * Matplotlib
#
#     * Plot and visualize data
#
# * Scipy
#
#     * Scientific math and analysis
